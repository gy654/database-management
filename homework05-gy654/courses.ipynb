# %% [markdown]
# # Instructions
# **1. Read the course schedule into a DataFrame**
#
# the frame should have the following columns:
# - Number-Section: the course number and section number
#
# Use your discretion to deal with issues encountered here (for example, some issues may include courses listed with two different course numbers!), but document what you've done and give some rationale for your methodology
#
# ⚠️ you may encounter an invisible space character (a zero width space) in the course number depending on how you extract the text (view the markup in Chrome's web inspector tools or try printing it out in Python)
#
# the easiest way to deal with this is to replace it with emtpy string (assuming s contains the zero width space): s.replace('\u200b', '')
# - Name: the name of the course
# - Instructor: the name of the professor
#
# Again, there may be issues here, such as multiple instructors; use your discretion, but describe what you've done and why
# - Time: the day(s) and time(s) the course meets
# (once you read in the data, you'll add a couple of rows)

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
import pandas as pd
import numpy as np

def html_to_table_schedule(link):
    with open(link, 'r') as f:
        dom = BeautifulSoup(f.read(), 'html')
    dom = dom.find_all("ul", class_="schedule-listing")[0]
    course_lists = dom.find_all('li')
    id_list = []
    name_list = []
    instructor_list = []
    time_list = []
    for course in course_lists:
        try:
            id = course['id']
        except:
            id = 'Not Found.'
        id_list.append(id.upper())

        try:
            name = course.find_all('a', class_ = 'expand')[0].text.replace('\n', '').strip(' ')
        except:
            name = 'Not Found'
        name_list.append(name)

        try:
            instructor = course.find_all('span', class_ = 'col-xs-12 col-sm-2')[0].text.replace('\n', '').strip(' ')
        except:
            instructor = 'Not Found'
        instructor_list.append(instructor)

        try:
            time = course.find_all('span', class_ ="col-xs-12 col-sm-2")[1].text
        except:
            time = 'Not Found'
        time_list.append(time)

    table = pd.DataFrame(np.array([id_list, name_list, instructor_list, time_list]).T, columns = ['Number-Section', 'Name', 'Instructor', 'Time'])
    return table

schedule_link = 'course_schedule.html'
schedule_table = html_to_table_schedule(schedule_link)
schedule_table
# Out:
#       Number-Section                                               Name  \
# 0    CSCI-GA1170-001                             Fundamental Algorithms
# 1    CSCI-GA1170-002                  Fundamental Algorithms Recitation
# 2    CSCI-GA1170-003                             Fundamental Algorithms
# 3    CSCI-GA1170-004                  Fundamental Algorithms Recitation
# 4    CSCI-GA1170-005                  Fundamental Algorithms Recitation
# ..               ...                                                ...
# 155  CSCI-UA0480-046         Special Topics: Intro to Social Networking
# 156  CSCI-UA0480-052        Special Topics: Algorithmic Problem Solving
# 157  CSCI-UA0480-057        Special Topics: Natural Language Processing
# 158  CSCI-UA0480-069  Special Topics: Agile Software Development and...
# 159  CSCI-UA0480-071  Special Topics:                               ...
#
#              Instructor             Time
# 0              Chee Yap    T 4:55-6:55PM
# 1         Daniel Feldan    R 5:55-6:45PM
# 2         Richard  Cole    W 4:55-6:55PM
# 3     Zachary DeStefano    F 4:55-5:45PM
# 4            Zeming Lin    R 5:55-6:45PM
# ..                  ...              ...
# 155  Bhubaneswar Mishra  TR 12:30-1:45PM
# 156    Joanna Klukowska  MW 12:30-1:45PM
# 157         Adam Meyers   TR 2:00-3:15PM
# 158      Amos Bloomberg  TR 12:30-1:45PM
# 159          Evan Korth   TR 3:30-4:45PM
#
# [160 rows x 4 columns]

# %% [markdown]
# - once you've read in your data, break apart the Number-Section column into two separate columns: Number and Section
#
#     - Number is something like CSCI-UA.0480
#
#     - Section is something like 001
#     - try to use regular expressions with groups to do this
#         - the str accessor method to use is extract
#         - check out the end of the regex slides or the official pandas docs
#     - show:
#         - info to show the data types and counts
#         - the first 5 rows
#         - the last 5 rows
#         - a random sampling of 5 rows

# %%
schedule_table['Number'] = schedule_table['Number-Section'].str.extract(r'(.*)-')
schedule_table['Section'] = schedule_table['Number-Section'].str.extract(r'(\d+)')
schedule_table
# Out:
#       Number-Section                                               Name  \
# 0    CSCI-GA1170-001                             Fundamental Algorithms
# 1    CSCI-GA1170-002                  Fundamental Algorithms Recitation
# 2    CSCI-GA1170-003                             Fundamental Algorithms
# 3    CSCI-GA1170-004                  Fundamental Algorithms Recitation
# 4    CSCI-GA1170-005                  Fundamental Algorithms Recitation
# ..               ...                                                ...
# 155  CSCI-UA0480-046         Special Topics: Intro to Social Networking
# 156  CSCI-UA0480-052        Special Topics: Algorithmic Problem Solving
# 157  CSCI-UA0480-057        Special Topics: Natural Language Processing
# 158  CSCI-UA0480-069  Special Topics: Agile Software Development and...
# 159  CSCI-UA0480-071  Special Topics:                               ...
#
#              Instructor             Time       Number Section
# 0              Chee Yap    T 4:55-6:55PM  CSCI-GA1170    1170
# 1         Daniel Feldan    R 5:55-6:45PM  CSCI-GA1170    1170
# 2         Richard  Cole    W 4:55-6:55PM  CSCI-GA1170    1170
# 3     Zachary DeStefano    F 4:55-5:45PM  CSCI-GA1170    1170
# 4            Zeming Lin    R 5:55-6:45PM  CSCI-GA1170    1170
# ..                  ...              ...          ...     ...
# 155  Bhubaneswar Mishra  TR 12:30-1:45PM  CSCI-UA0480    0480
# 156    Joanna Klukowska  MW 12:30-1:45PM  CSCI-UA0480    0480
# 157         Adam Meyers   TR 2:00-3:15PM  CSCI-UA0480    0480
# 158      Amos Bloomberg  TR 12:30-1:45PM  CSCI-UA0480    0480
# 159          Evan Korth   TR 3:30-4:45PM  CSCI-UA0480    0480
#
# [160 rows x 6 columns]

# %%
# info to show the data types and counts
schedule_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Number-Section  160 non-null    object
#  1   Name            160 non-null    object
#  2   Instructor      160 non-null    object
#  3   Time            160 non-null    object
#  4   Number          160 non-null    object
#  5   Section         160 non-null    object
# dtypes: object(6)
# memory usage: 7.6+ KB

# %%
# the first 5 rows
schedule_table.head(5)
# Out:
#     Number-Section                               Name         Instructor  \
# 0  CSCI-GA1170-001             Fundamental Algorithms           Chee Yap
# 1  CSCI-GA1170-002  Fundamental Algorithms Recitation      Daniel Feldan
# 2  CSCI-GA1170-003             Fundamental Algorithms      Richard  Cole
# 3  CSCI-GA1170-004  Fundamental Algorithms Recitation  Zachary DeStefano
# 4  CSCI-GA1170-005  Fundamental Algorithms Recitation         Zeming Lin
#
#             Time       Number Section
# 0  T 4:55-6:55PM  CSCI-GA1170    1170
# 1  R 5:55-6:45PM  CSCI-GA1170    1170
# 2  W 4:55-6:55PM  CSCI-GA1170    1170
# 3  F 4:55-5:45PM  CSCI-GA1170    1170
# 4  R 5:55-6:45PM  CSCI-GA1170    1170

# %%
# the last 5 rows
schedule_table.tail(5)
# Out:
#       Number-Section                                               Name  \
# 155  CSCI-UA0480-046         Special Topics: Intro to Social Networking
# 156  CSCI-UA0480-052        Special Topics: Algorithmic Problem Solving
# 157  CSCI-UA0480-057        Special Topics: Natural Language Processing
# 158  CSCI-UA0480-069  Special Topics: Agile Software Development and...
# 159  CSCI-UA0480-071  Special Topics:                               ...
#
#              Instructor             Time       Number Section
# 155  Bhubaneswar Mishra  TR 12:30-1:45PM  CSCI-UA0480    0480
# 156    Joanna Klukowska  MW 12:30-1:45PM  CSCI-UA0480    0480
# 157         Adam Meyers   TR 2:00-3:15PM  CSCI-UA0480    0480
# 158      Amos Bloomberg  TR 12:30-1:45PM  CSCI-UA0480    0480
# 159          Evan Korth   TR 3:30-4:45PM  CSCI-UA0480    0480

# %%
# a random sampling of 5 rows
schedule_table.sample(5)
# Out:
#       Number-Section                                        Name  \
# 19   CSCI-GA2433-001                            Database Systems
# 5    CSCI-GA1170-007           Fundamental Algorithms Recitation
# 128  CSCI-UA0201-061  Computer Systems Organization - Recitation
# 113  CSCI-UA0102-061                Data Structures - Recitation
# 72   CSCI-GA3870-001          Internship In Computer Science MS*
#
#                        Instructor             Time       Number Section
# 19         Jean-Claude Franchitti    R 4:55-6:55PM  CSCI-GA2433    2433
# 5                     Nick Lourie    F 4:55-5:45PM  CSCI-GA1170    1170
# 128                   Samvid Zare    T 4:55-6:10PM  CSCI-UA0201    0201
# 113  Harshitha Raghavan Devarajan  R 11:00-12:15PM  CSCI-UA0102    0102
# 72                          STAFF                -  CSCI-GA3870    3870

# %% [markdown]
# **2. Read the course catalog into a DataFrame**
# - the frame should have the following columns:
#     - Number: the course number
#     - Prereqs: a text description of the prerequisites
#     - Points: the number of credits
# - here's example of a DataFrame with some course catalog rows (again, the data is from another semester)

# %%
def html_to_table_catalog(link):
    with open(link, 'r') as f:
        dom = BeautifulSoup(f.read(), 'html')
    dom = dom.select("ul", class_ = 'courses-listing')[2]
    course_list = dom.select('li')
    id_list = []
    prereqs_list = []
    points_list = []
    for course in course_list:
        try:
            id = course['id'].upper()
        except:
            id = 'Not Found'
        id_list.append(id)
        
        try:
            prereq = course.find_all('p', class_ = 'bold')[-1].text.replace('Prerequisites: ', '')
        except:
            prereq = 'Not Found'
        prereqs_list.append(prereq)

        try:
            s = course.find_all('p', class_ = 'bold')[1].text.replace('\n', '').strip(' ')
            match = re.search(r'(\d) Points', s)
            points = int(match[1])
        except:
            points = np.nan
        points_list.append(points)
        
        catalog_table = pd.DataFrame(np.array([id_list, prereqs_list, points_list ]).T, columns = ['Number', 'Prereqs', 'Points'])
    return catalog_table
catalog_link = 'course_catalog.html'
catalog_table = html_to_table_catalog(catalog_link)
catalog_table
# Out:
#           Number                                            Prereqs Points
# 0    CSCI-GA1133                                               None      4
# 1    CSCI-GA1144           CSCI-GA 1133 or departmental permission.      4
# 2    CSCI-GA1170  At least one year of experience with a high-le...      3
# 3    CSCI-GA1180                                               None      3
# 4    CSCI-GA2110  Students taking this class should already have...      3
# ..           ...                                                ...    ...
# 91   CSCI-UA0897  Restricted to declared computer science majors...      4
# 92   CSCI-UA0898  Restricted to declared computer science majors...      4
# 93   CSCI-UA0997  Permission of the department. Does not satisfy...      4
# 94   CSCI-UA0998  Permission of the department. Does not satisfy...      4
# 95  FRSEM-UA0597  Some programming experience in Python, Java, J...      4
#
# [96 rows x 3 columns]

# %% [markdown]
# - show:
#     - info to show the data types and counts
#     - the first 5 rows
#     - the last 5 rows
#     - a random sampling of 5 rows
# - use a similar parsing strategy as above to read in this DataFrame

# %%
# infor to show the data types and counts
catalog_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Number   96 non-null     object
#  1   Prereqs  96 non-null     object
#  2   Points   96 non-null     object
# dtypes: object(3)
# memory usage: 2.4+ KB

# %%
# the first 5 rows
catalog_table.head(5)
# Out:
#         Number                                            Prereqs Points
# 0  CSCI-GA1133                                               None      4
# 1  CSCI-GA1144           CSCI-GA 1133 or departmental permission.      4
# 2  CSCI-GA1170  At least one year of experience with a high-le...      3
# 3  CSCI-GA1180                                               None      3
# 4  CSCI-GA2110  Students taking this class should already have...      3

# %%
# the last 5 rows
catalog_table.tail(5)
# Out:
#           Number                                            Prereqs Points
# 91   CSCI-UA0897  Restricted to declared computer science majors...      4
# 92   CSCI-UA0898  Restricted to declared computer science majors...      4
# 93   CSCI-UA0997  Permission of the department. Does not satisfy...      4
# 94   CSCI-UA0998  Permission of the department. Does not satisfy...      4
# 95  FRSEM-UA0597  Some programming experience in Python, Java, J...      4

# %%
# the last 5 rows
catalog_table.sample(5)
# Out:
#          Number                                            Prereqs Points
# 50  CSCI-GA3210                     Strong mathematical background      3
# 21  CSCI-GA2437  Prerequisites include experience with Hadoop, ...      3
# 57  CSCI-GA3840  Approval of a faculty adviser and the Director...      6
# 86  CSCI-UA0479  Data Structures (CSCI-UA 102). Students that c...      4
# 92  CSCI-UA0898  Restricted to declared computer science majors...      4

# %% [markdown]
# **3. Put together both DataFrames**
# - create a new DataFrame by….
# - finding a way to show all scheduled classes in the semester along with their points and prereqs
# - only show the following columns, in this order:
#     - Number: course number
#     - Name: course name
#     - Instructor: professor's name
#     - Time: meeting time
#     - Prereqs: course prerequisites
#     - Points: number of credits
# - hints:
#     - use pd.merge to do this
#     - how=left will keep all rows in the first DataFrame

# %%
schedule_table
# Out:
#       Number-Section                                               Name  \
# 0    CSCI-GA1170-001                             Fundamental Algorithms
# 1    CSCI-GA1170-002                  Fundamental Algorithms Recitation
# 2    CSCI-GA1170-003                             Fundamental Algorithms
# 3    CSCI-GA1170-004                  Fundamental Algorithms Recitation
# 4    CSCI-GA1170-005                  Fundamental Algorithms Recitation
# ..               ...                                                ...
# 155  CSCI-UA0480-046         Special Topics: Intro to Social Networking
# 156  CSCI-UA0480-052        Special Topics: Algorithmic Problem Solving
# 157  CSCI-UA0480-057        Special Topics: Natural Language Processing
# 158  CSCI-UA0480-069  Special Topics: Agile Software Development and...
# 159  CSCI-UA0480-071  Special Topics:                               ...
#
#              Instructor             Time       Number Section
# 0              Chee Yap    T 4:55-6:55PM  CSCI-GA1170    1170
# 1         Daniel Feldan    R 5:55-6:45PM  CSCI-GA1170    1170
# 2         Richard  Cole    W 4:55-6:55PM  CSCI-GA1170    1170
# 3     Zachary DeStefano    F 4:55-5:45PM  CSCI-GA1170    1170
# 4            Zeming Lin    R 5:55-6:45PM  CSCI-GA1170    1170
# ..                  ...              ...          ...     ...
# 155  Bhubaneswar Mishra  TR 12:30-1:45PM  CSCI-UA0480    0480
# 156    Joanna Klukowska  MW 12:30-1:45PM  CSCI-UA0480    0480
# 157         Adam Meyers   TR 2:00-3:15PM  CSCI-UA0480    0480
# 158      Amos Bloomberg  TR 12:30-1:45PM  CSCI-UA0480    0480
# 159          Evan Korth   TR 3:30-4:45PM  CSCI-UA0480    0480
#
# [160 rows x 6 columns]

# %%
catalog_table
# Out:
#           Number                                            Prereqs Points
# 0    CSCI-GA1133                                               None      4
# 1    CSCI-GA1144           CSCI-GA 1133 or departmental permission.      4
# 2    CSCI-GA1170  At least one year of experience with a high-le...      3
# 3    CSCI-GA1180                                               None      3
# 4    CSCI-GA2110  Students taking this class should already have...      3
# ..           ...                                                ...    ...
# 91   CSCI-UA0897  Restricted to declared computer science majors...      4
# 92   CSCI-UA0898  Restricted to declared computer science majors...      4
# 93   CSCI-UA0997  Permission of the department. Does not satisfy...      4
# 94   CSCI-UA0998  Permission of the department. Does not satisfy...      4
# 95  FRSEM-UA0597  Some programming experience in Python, Java, J...      4
#
# [96 rows x 3 columns]

# %%
combined = pd.merge(schedule_table, catalog_table, on = 'Number', how = 'left')
combined = combined[['Number', 'Name', 'Instructor', 'Time', 'Prereqs', 'Points']]
combined
# Out:
#           Number                                               Name  \
# 0    CSCI-GA1170                             Fundamental Algorithms
# 1    CSCI-GA1170                  Fundamental Algorithms Recitation
# 2    CSCI-GA1170                             Fundamental Algorithms
# 3    CSCI-GA1170                  Fundamental Algorithms Recitation
# 4    CSCI-GA1170                  Fundamental Algorithms Recitation
# ..           ...                                                ...
# 155  CSCI-UA0480         Special Topics: Intro to Social Networking
# 156  CSCI-UA0480        Special Topics: Algorithmic Problem Solving
# 157  CSCI-UA0480        Special Topics: Natural Language Processing
# 158  CSCI-UA0480  Special Topics: Agile Software Development and...
# 159  CSCI-UA0480  Special Topics:                               ...
#
#              Instructor             Time  \
# 0              Chee Yap    T 4:55-6:55PM
# 1         Daniel Feldan    R 5:55-6:45PM
# 2         Richard  Cole    W 4:55-6:55PM
# 3     Zachary DeStefano    F 4:55-5:45PM
# 4            Zeming Lin    R 5:55-6:45PM
# ..                  ...              ...
# 155  Bhubaneswar Mishra  TR 12:30-1:45PM
# 156    Joanna Klukowska  MW 12:30-1:45PM
# 157         Adam Meyers   TR 2:00-3:15PM
# 158      Amos Bloomberg  TR 12:30-1:45PM
# 159          Evan Korth   TR 3:30-4:45PM
#
#                                                Prereqs Points
# 0    At least one year of experience with a high-le...      3
# 1    At least one year of experience with a high-le...      3
# 2    At least one year of experience with a high-le...      3
# 3    At least one year of experience with a high-le...      3
# 4    At least one year of experience with a high-le...      3
# ..                                                 ...    ...
# 155                    Topics determine prerequisites.      4
# 156                    Topics determine prerequisites.      4
# 157                    Topics determine prerequisites.      4
# 158                    Topics determine prerequisites.      4
# 159                    Topics determine prerequisites.      4
#
# [160 rows x 6 columns]

# %% [markdown]
# **4. Conclusion**
# - did you spot any anomalies, discrepancies, or unexpected data or relationships between data?
# - if so, in a markdown cell, describe any problem(s) you saw
# - additionally, describe how you might fix them (or if you already fixed them!)
# - lastly, based on the resulting DataFrame, describe the behavior of how=left on these particular DataFrames
# - if you need to see all rows, use pd.set_option('display.max_rows', 200)
# ***

# %% [markdown]
# There might be multiple class namse associated with one course number. Also there are duplicates in terms of courses in this new table. Sometimes, several rows refer to the exact same course, but the scraping program and merge create a distince row for each meeting time.

# %%
combined[32:38]
# Out:
#          Number                                             Name  \
# 32  CSCI-GA2630      Foundations of Networks and Mobile Systems*
# 33  CSCI-GA2630  Foundations of Networks and Mobile Systems Lab*
# 34  CSCI-GA2630      Foundations of Networks and Mobile Systems*
# 35  CSCI-GA2630  Foundations of Networks and Mobile Systems Lab*
# 36  CSCI-GA2810                           Design and Innovation*
# 37  CSCI-GA2810                       Design and Innovation Lab*
#
#                       Instructor             Time Prereqs Points
# 32  Lakshminarayanan Subramanian  T 10:00-11:50AM    None      3
# 33  Lakshminarayanan Subramanian    T 9:00-9:50AM    None      3
# 34  Lakshminarayanan Subramanian   M 12:30-2:30PM    None      3
# 35  Lakshminarayanan Subramanian    W 1:30-2:20PM    None      3
# 36                 Gary Zamchick  F 10:15-12:15PM    None      3
# 37                 Gary Zamchick   F 12:30-1:20PM    None      3

# %% [markdown]
# I solve the first issue by grouping by Number, class Name, and Instructor. We can see more clearly that a class number may have multiple class names associated with it.
# I solve the second issue by merging the meeting times of the same course(with the same course number, name and instructor).

# %%
pd.set_option('display.max_rows', 200)
array_agg = lambda x: '/'.join(x)

merge_time= combined.groupby(['Number', 'Name', 'Instructor']).agg({'Time': array_agg})
merge_time
# Out:
#                                                                                                                                               Time
# Number      Name                                               Instructor
# CSCI-GA1170 Fundamental Algorithms                             Chee Yap                                                              T 4:55-6:55PM
#                                                                Richard  Cole                                                         W 4:55-6:55PM
#             Fundamental Algorithms Recitation                  Daniel Feldan                                                         R 5:55-6:45PM
#                                                                Nick Lourie                                                           F 4:55-5:45PM
#                                                                Zachary DeStefano                                                     F 4:55-5:45PM
#                                                                Zeming Lin                                                            R 5:55-6:45PM
# CSCI-GA1180 Mathematical Techniques For CS Applications        Parijat Dube                                                          M 7:10-9:10PM
# CSCI-GA2110 Programming Languages                              Cory Plock                                                            M 4:55-6:55PM
#                                                                Thomas Wies                                                           T 4:55-6:55PM
#             Programming Languages Recitation                   Elaine Li                                                             F 5:55-6:45PM
#                                                                Jahnvi Arya                                                           R 4:55-5:45PM
#                                                                Nisarg Patel                                                          F 5:55-6:45PM
#                                                                Yashaswi Shah                                                         R 4:55-5:45PM
# CSCI-GA2112 Scientific Computing                               Jonathan Goodman                                                      R 5:10-7:00PM
# CSCI-GA2250 Operating Systems                                  Hubertus Franke                                                       M 7:10-9:10PM
# CSCI-GA2262 Data Communications and Networks                   Jean-Claude Franchitti                                                R 7:10-9:10PM
# CSCI-GA2270 Computer Graphics                                  Gizem Kayar                                                           W 7:10-9:10PM
# CSCI-GA2271 Computer Vision                                    Rob Fergus                                                            R 7:10-9:10PM
# CSCI-GA2420 Numerical Methods I                                Benjamin Peherstorfer                                                 M 5:10-7:00PM
# CSCI-GA2433 Database Systems                                   Jean-Claude Franchitti                                                R 4:55-6:55PM
# CSCI-GA2434 Advanced Database Systems                          Dennis  Shasha                                                        R 4:55-6:55PM
# CSCI-GA2436 Realtime and Big Data Analytics                    Yang Tang                                                             W 7:10-9:10PM
# CSCI-GA2437 Big Data Application Development                   Yang Tang                                                             M 7:10-9:10PM
# CSCI-GA2560 Artificial Intelligence                            Paul Bethe                                                            M 4:55-6:55PM
# CSCI-GA2565 Machine Learning                                   Rajesh Ranganath                                                      T 4:55-6:55PM
# CSCI-GA2566 Foundations Of Machine Learning*                   CANCELLED                                                                         -
# CSCI-GA2569 Inference and Representation                       Joan Bruna                                                           R 12:00-1:40PM
#             Inference and Representation Lab                   Lei Chen                                                            M 11:15-12:05PM
# CSCI-GA2572 Deep Learning                                      Alfredo Canziani                                                      W 4:55-6:55PM
#             Deep Learning Lab                                  Alfredo Canziani                                                      R 4:55-5:45PM
# CSCI-GA2590 Natural Language Processing                        Adam Meyers                                                         W 10:15-12:15PM
# CSCI-GA2621 Distributed Systems                                Aurojit Panda                                                         W 4:55-6:55PM
# CSCI-GA2630 Foundations of Networks and Mobile Systems Lab*    Lakshminarayanan Subramanian                            T 9:00-9:50AM/W 1:30-2:20PM
#             Foundations of Networks and Mobile Systems*        Lakshminarayanan Subramanian                         T 10:00-11:50AM/M 12:30-2:30PM
# CSCI-GA2810 Design and Innovation Lab*                         Gary Zamchick                                                        F 12:30-1:20PM
#             Design and Innovation*                             Gary Zamchick                                                       F 10:15-12:15PM
# CSCI-GA2820 DevOps and Agile Methodologies                     John Rofrano                                            T 4:55-6:55PM/W 4:55-6:55PM
#             DevOps and Agile Methodologies Lab                 John Rofrano                                            T 7:10-8:00PM/W 7:10-8:00PM
# CSCI-GA2945 Adv Topics Num Analysis: Computational Electrom... Michael O'Neil                                                        R 1:25-3:15PM
#             Adv Topics Num Analysis: Monte Carlo Methods       Jonathan  Weare                                                     W 11:00-12:50PM
# CSCI-GA2965 Heuristic Problem Solving                          Dennis  Shasha                                                        R 7:10-9:10PM
# CSCI-GA3033 Special Topics in Data Science: Bayesian Machin... Tim Rudner                                                            T 4:55-6:35PM
#             Special Topics in Data Science: Bayesian Machin... Nate Gruver                                                           W 8:10-9:00PM
#             Special Topics in Data Science: Machine Learnin... Divyam Madaan                                                         F 1:30-2:20PM
#             Special Topics:                                ... CANCELLED                                                                         -
#             Special Topics:                                ... I-Hsin Chung                                   ...                    R 4:55-6:55PM
#             Special Topics:                                ... Joseph Bonneau                                                        T 7:10-9:10PM
#             Special Topics:                                ... Maria Lorena Carlo Unda                                               T 7:10-9:10PM
#             Special Topics:                                ... Mohamed Zahran                                                        W 4:55-6:55PM
#             Special Topics:                                ... Parijat Dube                                                          T 7:10-9:10PM
#             Special Topics:                                ... Sumit Chopra                                                          W 7:10-9:10PM
#             Special Topics:                                ... Anasse Bari                                                           W 4:55-6:55PM
# CSCI-GA3110 Honors Programming Languages                       Patrick  Cousot                                                      TR 3:30-4:45PM
# CSCI-GA3205 Applied Cryptography & Network Security            Mazdak Zamani                                                         T 7:10-9:10PM
# CSCI-GA3520 Honors Analysis of Algorithms                      Subhash Khot                                                        TR 9:30-10:45AM
# CSCI-GA3812 Information Technology Projects *                  Jean-Claude Franchitti                                                M 6:10-9:10PM
# CSCI-GA3813 Adv Lab MS *                                       STAFF                                                                    -/ -/ -/ -
#             Adv Lab PhD **                                     STAFF                                                                    -/ -/ -/ -
# CSCI-GA3840 Master's Thesis Research *                         STAFF                                                                             -
# CSCI-GA3850 PhD Seminar: Cryptography **                       Marshall Ball                                                         W 1:00-3:00PM
#             PhD Seminar: Formal Methods **                     Thomas Wies                                                         R 11:00-12:30PM
# CSCI-GA3860 PhD Thesis Research **                             STAFF                                                                             -
# CSCI-GA3870 Internship In Computer Science MS*                 STAFF                                                                             -
#             Internship in Computer Science PhD*                STAFF                                                                             -
# CSCI-UA0002 Intro To Computer Programming (No Prior Experie... Amanda Steigman                                                      MW 8:00-9:15AM
#                                                                Craig Kapp                                                          MW 9:30-10:45AM
#                                                                David Prager                                                        MW 12:30-1:45PM
#                                                                Emily Zhao                                                           TR 4:55-6:10PM
#                                                                Joshua Clayton                                                       MW 3:30-4:45PM
#                                                                Julie Lizardo                                       TR 9:30-10:45AM/TR 12:30-1:45PM
#                                                                Khye Borg Liew                                                       TR 3:30-4:45PM
#                                                                Matthew Zeidenberg                                                   TR 2:00-3:15PM
#                                                                Michell Cardona                                                      TR 6:20-7:35PM
#                                                                Mihir Patil                                                         MW 9:30-10:45AM
#                                                                Susan Liao                                                           TR 8:00-9:15AM
#                                                                Zoe Robert                                                         MW 11:00-12:15PM
# CSCI-UA0003 Intro to Computer Programming (Limited Prior Ex... Mauricio Arias Hernandez                                           TR 11:00-12:15PM
# CSCI-UA0004 Intro to Web Design & Computer Principles          Adam Scher                                                           TR 8:00-9:15AM
#                                                                Alvaro Olsen                                          MW 8:00-9:15AM/MW 3:30-4:45PM
#                                                                Joshua Clayton                                                     TR 11:00-12:15PM
#                                                                Julie Lizardo                                                       MW 12:30-1:45PM
#                                                                Mark Ramos                                                         MW 11:00-12:15PM
# CSCI-UA0060 Database Design And Implementation                 Amos Bloomberg                                                     TR 11:00-12:15PM
# CSCI-UA0061 Web Development And Programming                    Sana Odeh                                                            MW 3:30-4:45PM
# CSCI-UA0101 Intro To Computer Science                          Anasse Bari                                                          TR 3:30-4:45PM
#                                                                Candido Cabo                                                        TR 12:30-1:45PM
#                                                                Duygu Ataman                                                         MW 2:00-3:15PM
#                                                                Gizem Kayar                                                         TR 9:30-10:45AM
#                                                                Hilbert Gene Locklear                                MW 12:30-1:45PM/MW 3:30-4:45PM
#                                                                Nader Nassar                                                         MW 8:00-9:15AM
#                                                                Sana Odeh                                             TR 2:00-3:15PM/MW 4:55-6:10PM
# CSCI-UA0102 Data Structures                                    Anasse Bari                                                        TR 11:00-12:15PM
#                                                                Evan Korth                                                          TR 12:30-1:45PM
#                                                                Joanna Klukowska                                                     MW 8:00-9:15AM
#             Data Structures - Recitation                       Adithya Viswanathan                                                   F 4:55-6:10PM
#                                                                Chris Davidson                                                        W 3:30-4:45PM
#                                                                Harshitha Raghavan Devarajan                                        R 11:00-12:15PM
#                                                                Joseph Cappadona                                     R 11:00-12:15PM/R 12:30-1:45PM
#                                                                Lauren DiGiovanni                                                     F 4:55-6:10PM
#                                                                Siyi Sun                                                            W 11:00-12:15PM
#                                                                Swarna Swapna Ilamathy                                               T 9:30-10:45AM
#                                                                Vaibhav Mavi                                                          F 4:55-6:10PM
#                                                                Xujin He                                                             R 9:30-10:45AM
# CSCI-UA0201 Computer Systems Organization                      Douglas Moody                                                       MW 9:30-10:45AM
#                                                                Gizem Kayar                                                          TR 3:30-4:45PM
#                                                                Hasan Aljabbouli                                                     MW 3:30-4:45PM
#                                                                Jinyang Li                                                          TR 9:30-10:45AM
#             Computer Systems Organization - Recitation         Anish Mahishi                                                         T 4:55-6:10PM
#                                                                Fakhruddin Pattan                                       R 8:00-9:15AM/F 8:00-9:15AM
#                                                                Harshitha Raghavan Devarajan                                         T 9:30-10:45AM
#                                                                Jaya Amit Sai Gurrala                                                T 9:30-10:45AM
#                                                                Samvid Zare                                                           T 4:55-6:10PM
#                                                                Shantanu Dahiya                                                       M 8:00-9:15AM
#                                                                Shraddha Thyagarajan Iyer                                             M 8:00-9:15AM
# CSCI-UA0202 Operating Systems                                  Mohamed Zahran                                                     TR 11:00-12:15PM
#                                                                Yang Tang                                                            MW 4:55-6:10PM
# CSCI-UA0310 Basic Algorithms                                   Marshall Ball                                                       TR 12:30-1:45PM
#                                                                Oded Regev                                                           MW 2:00-3:15PM
#                                                                Seyed Hossein Nassajianmojarrad                                     TR 12:30-1:45PM
#             Basic Algorithms - Recitation                      Eli Goldin                                                            R 2:00-3:15PM
#                                                                Peter Fenteany                                                        R 2:00-3:15PM
#                                                                Vladimir Podolskii                                     W 8:00-9:15AM/W 12:30-1:45PM
# CSCI-UA0380 Topics of General Interest:  Interactive Computing Craig Kapp                                                           MW 3:30-4:45PM
# CSCI-UA0381 Programming Tools for the Data Scientist           Hasan Aljabbouli                                                    TR 12:30-1:45PM
# CSCI-UA0467 Applied Internet Technology                        Joseph Versoza                                      TR 9:30-10:45AM/MW 12:30-1:45PM
# CSCI-UA0470 Object Oriented Programming                        Hasan Aljabbouli                                                    MW 9:30-10:45AM
# CSCI-UA0472 Artificial Intelligence                            Ernest Davis                                                       TR 11:00-12:15PM
# CSCI-UA0473 Intro To Machine Learning                          Lerrel Pinto                                                         TR 2:00-3:15PM
#             Intro to Machine Learning - Recitation             Lerrel Pinto                                            M 8:00-9:15AM/W 8:00-9:15AM
# CSCI-UA0474 Software Engineering                               Amos Bloomberg                                                       MW 2:00-3:15PM
# CSCI-UA0476 Processing Big Data for Analytics Applications     Ann Malavet                                                          TR 8:00-9:15AM
# CSCI-UA0479 Data Management and Analysis                       Joseph Versoza                                                     MW 11:00-12:15PM
#                                                                Matthew Zeidenberg                                  MW 3:30-4:45PM/MW 11:00-12:15PM
# CSCI-UA0480 Special Topics:                                ... Evan Korth                                                           TR 3:30-4:45PM
#             Special Topics: Agile Software Development and ... Amos Bloomberg                                                      TR 12:30-1:45PM
#             Special Topics: Algorithmic Problem Solving        Joanna Klukowska                                                    MW 12:30-1:45PM
#             Special Topics: Computer Graphics                  Kenneth Perlin                                                       TR 8:00-9:15AM
#             Special Topics: Computer Vision                    Davi Geiger                                                          TR 4:55-6:10PM
#             Special Topics: Intro to Social Networking         Bhubaneswar Mishra                                                  TR 12:30-1:45PM
#             Special Topics: Natural Language Processing        Adam Meyers                                                          TR 2:00-3:15PM

# %%
print(f'The first table contains: {len(schedule_table.Number.unique())} distinct course numbers and course info.')
print(f'The second table contains: {len(catalog_table.Number.unique())} distinct course numbers and their prerequisites.')
# Out:
# The first table contains: 55 distinct course numbers and course info.
# The second table contains: 96 distinct course numbers and their prerequisites.

# %% [markdown]
# Merging the two tables with `how = left` ensures that all entries from the first table are kept in the new table, regardless of whether the course number appears in the second table.
